# %% [markdown]
# <a href="https://colab.research.google.com/github/karldeguzman32/DSP/blob/main/58044_Lab01_Pyrates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 01: Signals and Media

# %%
import numpy as np
import matplotlib.pyplot as plt

# !git clone https://github.com/AllenDowney/ThinkDSP.git 
import os
import sys
sys.path.insert(0, 'ThinkDSP/code/') 
import thinkdsp
import matplotlib.pyplot as plt
import IPython
# Out:
# fatal: destination path 'ThinkDSP' already exists and is not an empty directory.

# %% [markdown]
# ### Part 1: One Dimensional Signals

# %% [markdown]
# ####Audio

# %%
## WAV File Format
race = thinkdsp.read_wave('F1.wav')
race.plot()
plt.show()
race.play()
IPython.display.Audio('F1.wav')
# Out:
# Writing sound.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
## MP3 File Format
Arcade = thinkdsp.read_wave('arcade.mp3')
race.plot()
plt.show()
race.play()
IPython.display.Audio('Arcade')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-15-badc8a747526> in <module>()
#       1 ## MP3 File Format
# ----> 2 Arcade = thinkdsp.read_wave('arcade.mp3')
#       3 race.plot()
#       4 plt.show()
#       5 race.play()
#
# /content/ThinkDSP/code/thinkdsp.py in read_wave(filename)
#      95     returns: Wave
#      96     """
# ---> 97     fp = open_wave(filename, "r")
#      98
#      99     nchannels = fp.getnchannels()
#
# /usr/lib/python3.7/wave.py in open(f, mode)
#     508             mode = 'rb'
#     509     if mode in ('r', 'rb'):
# --> 510         return Wave_read(f)
#     511     elif mode in ('w', 'wb'):
#     512         return Wave_write(f)
#
# /usr/lib/python3.7/wave.py in __init__(self, f)
#     162         # else, assume it is an open file object already
#     163         try:
# --> 164             self.initfp(f)
#     165         except:
# ...

# %% [markdown]
# ###Explanation
# Two audio file format was used for this laboratory activity, which are the MP3 and WAV. MP3 is commonly used to reduce file size into a smaller size which would lessen its quality in terms of bit rate and discard a certain part of its information, which would make a good use for listening. WAV is described as a raw audio format in which it is mostly used by audio producers or engineers since it is good for audio editing. The difference between the two audio file format is MP3 is compressed while WAV is uncompressed, in which makes WAV more advantaged to audio manipulation since it an audio signals converted into binary data. \\
#
# MP3 file format cannot be imported since it is not supported by Python. Supported audio file formats includes WAV and AIF, which are uncompressed formats. As observed in the error, it shows that the "file does not start with RIFF id". This could mean that program looks into the file format by identifying if it starts with an "RIFF id". When an audio file starts with an "RIFF id", then it is a WAV audio file format but in this case the audio file format used is an MP3. Therefore, the program did proceed on running since the file format does not start with a "RIFF id". A possible way to resolve this issue of using an unsupported or compressed audio file format is converted into a supported or uncompressed one. In this case MP3 was used then it could be converted into a WAV format for the program to proceed and run successfully.

# %% [markdown]
# ### Part 2: 2D Signals

# %%
import cv2

# %% [markdown]
# ###JPEG

# %%
jpeg_img = cv2.imread('starry_night.jpg')
plt.imshow(jpeg_img)

# %%
jpeg_colored = cv2.cvtColor(jpeg_img, cv2.COLOR_BGR2RGB)
plt.imshow(jpeg_colored)

# %% [markdown]
# ###PNG

# %%
png_img = cv2.imread('great_wave.png')
plt.imshow(png_img)

# %%
png_colored = cv2.cvtColor(png_img, cv2.COLOR_BGR2RGB)
plt.imshow(png_colored)

# %% [markdown]
# ###GIF

# %%
gif = cv2.imread('huwat.gif')
plt.imshow(gif)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-9eadafb5301d> in <module>()
#       1 gif = cv2.imread('huwat.gif')
# ----> 2 plt.imshow(gif)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...

# %% [markdown]
# ###Explanation
# Three image file format was used for this laboratory activity, which are the JPEG, PNG, and GIF. JPEG is used to reduce size of an image file for the sake of less consumption of storage by discarding some of its data and faster transfer. PNG is used to make an image in detail and in higher quality since it deals with more data and no loss. GIF is used to create an animated image data in which it deals with storing a collection of images. \\
#
# An error has occured on the program in using the GIF image file format showing "Image data of dtype object cannot be converted to float". This could mean that there is a problem in loading the image and displaying the loaded image. Understanding what the error interprets, the data type of GIF cannot be converted into float which stops the program to run before proceeding. \\
#
# The array of JPEG and PNG image file format contains an integer and float that suits the CV2's "imread" and PYPLOTS "imshow" function to work properly. However, the array of GIF image file format contains a string. This could mean that the data type of the image cannot be converted into float since it contains a string array that unables the used functions to work properly with GIF.
